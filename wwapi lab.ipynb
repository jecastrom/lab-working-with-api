# %% [markdown]
# Jorge Castro DAPT NOV 2021

# %% [markdown]
# # Lab | Working with APIs
#
# #### Instructions
#
# Following the class example, create a function that returns the price, names of origin and arrival airports and the name of the company. Do it for all the flights between two dates that cost the same.

# %%
import requests
import getpass

# %% [markdown]
# ## Lab solution

# %%
import requests
# Stablishing the API Call
url = "https://travelpayouts-travelpayouts-flight-data-v1.p.rapidapi.com/v1/prices/calendar"

querystring = {"calendar_type":"departure_date","destination":"PMI","origin":"BER","depart_date":"2022-06-01","currency":"EUR"}

headers = {
	"X-Access-Token": token,
	"X-RapidAPI-Host": "travelpayouts-travelpayouts-flight-data-v1.p.rapidapi.com",
	"X-RapidAPI-Key": key
}

# Storing the response on a variable called "response"
response = requests.request("GET", url, headers=headers, params=querystring)

# Creating a list with the main keys of our json data, in this case are the dates
dates_of_flights = list(response.json()['data'].keys())

# %%
# creating an empty DataFrame
flights = pd.DataFrame(columns=['price', 'origin', 'destination', 'airline'])

# %%
# Populating our dataframe with the json data looping through it
for i in range(len(dates_of_flights)):    
    
    flights = flights.append(pd.json_normalize(response.json()['data'][dates_of_flights[i]]['price']))
    
#return flights
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20024/2917661432.py in <module>
#       2 for i in range(len(dates_of_flights)):
#       3
# ----> 4     flights = flights.append(pd.json_normalize(response.json()['data'][dates_of_flights[i]]['price']))
#       5
#       6 #return flights
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     421         data = list(data)
#     422     else:
# --> 423         raise NotImplementedError
#     424
#     425     # check to see if a simple recursive function is possible to
#
# NotImplementedError:

# %%
flights
# Out:
#    price origin destination airline  flight_number               departure_at  \
# 0    155    BER         PMI      U2         5801.0  2022-04-28T06:00:00+02:00
# 1    164    BER         PMI      EW         8590.0  2022-04-29T09:15:00+02:00
# 2     84    BER         PMI      EW         6893.0  2022-05-01T18:35:00+02:00
# 3     82    BER         PMI      FR         1468.0  2022-05-02T20:50:00+02:00
# 4     39    BER         PMI      FR          280.0  2022-05-03T20:30:00+02:00
# 5     71    BER         PMI      FR          196.0  2022-05-05T08:50:00+02:00
# 6     82    BER         PMI      FR         1468.0  2022-05-06T20:50:00+02:00
# 7     41    BER         PMI      FR         2147.0  2022-05-07T20:55:00+02:00
# 8     40    BER         PMI      FR         1468.0  2022-05-09T20:50:00+02:00
# 9     48    BER         PMI      FR          280.0  2022-05-10T20:30:00+02:00
# 10   146    BER         PMI      FR         2147.0  2022-05-11T20:35:00+02:00
